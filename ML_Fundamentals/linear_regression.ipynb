# %% [markdown]
# ### Simple Linear Regression Problem
#
# . Salary Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Datasets/Salary_dataset.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
# %matplotlib inline
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.scatter(df['YearsExperience'],df['Salary'], color='red', marker='+')
plt.show()

# %% [markdown]
# - Create a class object from linear regression and fit the 2 df columns plotted

# %%
X = df[['YearsExperience']]
X
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y = df['Salary']
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
reg = LinearRegression()  # class object instance of LinearRegression
reg.fit(X,y)  # fit the model to the data
# Out:
# LinearRegression()

# %% [markdown]
# - Predicting

# %%
reg.predict([[10]])  # 10 years of experience
# Out:
# c:\Users\rafae\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([119347.82718107])

# %% [markdown]
# - Performance of model (R² - coefficient of determination), MAE, MSE

# %%
from sklearn.metrics import mean_absolute_error

# %%
reg.score(X,y)  # based on the R² score

mae = mean_absolute_error(y,reg.predict(X))

print(f"R² score: {reg.score(X,y)}")  # explanation of the variance of the data
print(f"MAE: {mae}")  # explanation of the error of the model
# Out:
# R² score: 0.9569566641435086
# MAE: 4644.201289443537

# %%
# %matplotlib inline
plt.xlabel('Years of Experience')  # label the x-axis
plt.ylabel('Salary')  # label the y-axis
plt.scatter(df['YearsExperience'],df['Salary'], color='red', marker='+')  # plot the data points
plt.plot(df['YearsExperience'],reg.predict(df[['YearsExperience']]), color='blue')   # plot the regression line - the line of best fit
plt.show()
